# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashas32106/bias-detection/blob/main/social_bias_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **FairSpeak: Combating Social Bias in Communication**

# %% [markdown]
# Welcome to our FairSpeak project presentation for the Social Bias Science Fair. This interactive Google Colab Notebook will guide you through our journey of developing a tool to detect social bias in text, addressing the hackathon rubric criteria, and showcasing our development process.

# %% [markdown]
# # **1. Introduction**

# %% [markdown]
# FairSpeak is a tool designed to detect social bias in written text, providing users with real-time feedback to promote inclusive and fair communication. Our project addresses the nuances of social bias, going beyond word-level tokenization to understand context and implicit biases.

# %% [markdown]
# # **2. Vision**

# %% [markdown]
# Contribution to Bias Detection:
#
# - FairSpeak advances the field by providing a sophisticated tool that detects subtle social biases in text, helping users recognize and correct biased language.
#
# Impact at Small Scale:
#
# - By integrating FairSpeak into everyday writing tools, we empower individuals to make immediate changes in their communication, fostering a culture of inclusivity.
#
# Uniqueness:
#
# - Unlike existing grammar checkers, FairSpeak specifically targets social bias, filling a gap in the market for tools that promote conscious and fair language use.

# %% [markdown]
# ![Screenshot 2024-09-29 143010.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Social Impact**

# %% [markdown]
# User Awareness:
#
# - FairSpeak educates users about the downstream effects of biased language, encouraging reflection and personal growth.
#
# Accessibility:
#
# - Our Chrome extension ensures low barriers to use, making the tool accessible to the average person without technical expertise.
#
# Benefit to Society:
#
# - By promoting inclusive language, FairSpeak contributes to reducing discrimination and fostering understanding across different social groups.

# %% [markdown]
# # **4. Technical Foundation**

# %% [markdown]
# Implementation Quality:
#
#  -The tool features an intuitive interface with real-time feedback, enhancing the user experience.
#
# Data Science/AI/ML Expertise:
#
#  -FairSpeak utilizes advanced NLP techniques and fine-tuned language models to detect nuanced social biases.
#
# Team Collaboration:
#
# - Our multidisciplinary team shares a strong understanding of AI/ML, social sciences, and user-centered design, ensuring a cohesive and effective solution.

# %% [markdown]
# # **5. Development Process**

# %% [markdown]
# ![ES Model.png](data:image/png;base64,...)

# %% [markdown]
# A demo of the functionality of the Ethical Spectical Model

# %% [markdown]
# ![Screenshot 2024-09-29 131921.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Challenges with Existing Models

# %% [markdown]
# - Limitations: The Ethical Spectical model operates on word-level tokenization, which is insufficient for capturing the complexities and context of social bias.
#
# - Google's Language Models: Proprietary models like Google's have strict safety filters that limit the analysis of sensitive content, hindering our ability to detect social bias effectively.

# %% [markdown]
# ### Decision to Move on to GPT

# %% [markdown]
# - To address nuanced biases, we required a model capable of understanding context beyond individual words.

# %% [markdown]
# ![Screenshot 2024-09-29 140942.png](data:image/png;base64,...)

# %% [markdown]
# # **6. Viable Product: Chrome Extension**

# %% [markdown]
# Overview:
#
# Developed a Chrome extension that integrates FairSpeak into users' browsers, providing real-time bias detection as they write.
#
# Features:
#
# - Highlights biased language
#
# - Provides explanations to educate users on why certain language may be biased.
#
#
# Accessibility and Impact:
#
# - Easy to install and use, making it accessible to a wide audience.
#
# - Encourages critical thinking, maximizing social impact.

# %% [markdown]
# # **8. Interactive Demo**

# %% [markdown]
# # **FairSpeak Chrome Extension**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Fine-Tuning Process:
#
# Trained the model on datasets containing examples of social bias and inclusive language.
#
# Iteratively tested and refined the model to improve accuracy and reduce false positives/negatives.

# %% [markdown]
# Comparing FreeSpeak to traditional assistants

# %% [markdown]
# ## **Test Trails**

# %%
JSON_schema_1 = {
    "type": "object",
    "properties": {
      "stereotypes": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "unfair_statements": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "generalizations": {
        "type": "array",
        "items": {
          "type": "string"
        }
      }
    }
  }

# %%
user_content = "Some might wonder why a sophomore in high school — busy with classes, band and sports — sought the attention of the U.S. Supreme Court, which ruled in my favor recently. Now, I can proceed with my case at the U.S. Court of Appeals for the 6th Circuit unencumbered, for now, by Biden-Harris administration overreach. The high court denied the administration’s request to start enforcing Title IX rule changes that could have a pretty big effect on the rest of my teenage years by allowing males into women’s spaces. Title IX is the federal law designed to create equal opportunities for female students in education and athletics, and I, through my attorneys with Alliance Defending Freedom, oppose the administration’s unlawful attempts to redefine it. So do women’s groups, scholars, 20 states and others who have now filed briefs in my support at the 6th Circuit. Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex. Sharing private space is hard enough, even with a sibling, a friend or someone your same age and sex. It’s that much harder if you’re sharing with someone who’s none of those things — especially if that someone is making crude, sexually harassing comments. I put up with that all through middle school. I chose to join my school’s track team, running the 4 x 100-meter races, pole vaulting and throwing shot put and discus. It was fun, and I was competitive — one of the top three girls in my school for those latter two events. That all changed when a male a grade behind me chose to identify as a girl and joined our team — focusing on the same sports I did. As seasons passed, I soon saw how male size and strength could beat even my greatest efforts — and those of most other girls, too. Over these last two years, this one student has displaced almost 300 different female athletes — beating them in competition and taking their places at meets — over 700 times. I saw a lot of that firsthand. Almost every day, in the locker room, out on the track and in the throwing pits for discus and shot put, this student made crude, sexually explicit comments about me and other girls — many of which I found physically threatening. And yet, I was expected to change clothes in front of — and go to the restroom in the same room with — the male making those comments. Some of us began wearing school clothes to practice or our practice clothes to classes just to avoid changing in front of this one student. Yes, we complained to our coaches and administrators, but we never heard back from any of them. This same student plays in the school’s marching band with me. This means there’s a good chance I’ll have to change in front of him for those events, too. Then, there are overnight trips, like the one I took last year for Youth and Government to visit our state capital. On those trips, school officials usually have four girls share a room. But some schools are letting males stay in those rooms, too — and often without adult chaperones around. All these things make me uncomfortable. I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl. I don’t like being that vulnerable, especially in front of someone who’s making leering, suggestive comments. For me and for most girls I know, the fact that males are participating in our sports takes all the fun out of competing. Not only does it make us feel unsafe, but the older we get, the more obvious it becomes that they’re going to beat us, more and more easily … that the records, the medals and the opportunities will be going to them. What’s the point of competing if we have no chance of winning? Why take the time and make the effort only to expose ourselves to sexual harassment and possibly worse, while coaches and administrators deliberately look the other way? Why bother to object to what’s happening when so many are waiting to call us \"transphobes\" just for expressing our feelings and concerns? Since I’m one grade above the male student I competed against, I had a small reprieve from all the frustrations I experienced in middle school. But this year, that student is entering high school. Once again, we’ll be on the same team, practicing the same sports, playing in the same band. Some people don’t seem to understand why that is a problem. I’m just glad that, at least for now, the Supreme Court did, and I hope the 6th Circuit will, too."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. Just return those viewpoints as a structured JSON object."
model='gpt-4o-mini'
temperature = 1
prompt_version = 1

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_1)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1043,
#     "output_tokens": 103,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00021824999999999997,
#     "completion_string": "{\"stereotypes\":[\"Assuming all males are inherently threatening or unsafe in shared spaces with females.\",\"Believing that transgender individuals in sports pose an unfair advantage for biological females.\"],\"unfair_statements\":[\"Claiming that the presence of a trans girl in sports is harmful to cisgender girls without acknowledging the complexities of gender identity.\"],\"generalizations\":[\"Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex.\",\"All girls feel unsafe around trans girls or boys in shared spaces.\"]}",
#     "prompt_version": 1,
#     "stereotypes": [
# ...

# %%
JSON_schema_2 = {
    "type": "object",
    "properties": {
      "racial_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "gender_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "age_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "religious_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "class_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "disability_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "sexual_orientation_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "cultural_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "body_size_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "nationalism_ethnocentrism": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "intersectional_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
    }
  }

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_2)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1089,
#     "output_tokens": 100,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00022334999999999998,
#     "completion_string": "{\"gender_bias\":[\"Opposition to the inclusion of transgender females in women's sports\",\"Concerns about safety and privacy in changing and restroom situations due to the presence of a transgender female\",\"Perception that male athletes have unfair advantages over female athletes in sports\",\"Expectations that female athletes should be uncomfortable in shared spaces with transgender females\",\"Expression of discomfort stemming from the actions of a transgender female athlete\"],\"intersectional_bias\":[\"Suggestions that transgender women threaten the safety and competitive fairness of cisgender female athletes\"]}",
#     "prompt_version": 1,
#     "gender_bias": [
# ...

# %%
user_content = "Some might wonder why a sophomore in high school — busy with classes, band and sports — sought the attention of the U.S. Supreme Court, which ruled in my favor recently. Now, I can proceed with my case at the U.S. Court of Appeals for the 6th Circuit unencumbered, for now, by Biden-Harris administration overreach. The high court denied the administration’s request to start enforcing Title IX rule changes that could have a pretty big effect on the rest of my teenage years by allowing males into women’s spaces. Title IX is the federal law designed to create equal opportunities for female students in education and athletics, and I, through my attorneys with Alliance Defending Freedom, oppose the administration’s unlawful attempts to redefine it. So do women’s groups, scholars, 20 states and others who have now filed briefs in my support at the 6th Circuit. Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex. Sharing private space is hard enough, even with a sibling, a friend or someone your same age and sex. It’s that much harder if you’re sharing with someone who’s none of those things — especially if that someone is making crude, sexually harassing comments. I put up with that all through middle school. I chose to join my school’s track team, running the 4 x 100-meter races, pole vaulting and throwing shot put and discus. It was fun, and I was competitive — one of the top three girls in my school for those latter two events. That all changed when a male a grade behind me chose to identify as a girl and joined our team — focusing on the same sports I did. As seasons passed, I soon saw how male size and strength could beat even my greatest efforts — and those of most other girls, too. Over these last two years, this one student has displaced almost 300 different female athletes — beating them in competition and taking their places at meets — over 700 times. I saw a lot of that firsthand. Almost every day, in the locker room, out on the track and in the throwing pits for discus and shot put, this student made crude, sexually explicit comments about me and other girls — many of which I found physically threatening. And yet, I was expected to change clothes in front of — and go to the restroom in the same room with — the male making those comments. Some of us began wearing school clothes to practice or our practice clothes to classes just to avoid changing in front of this one student. Yes, we complained to our coaches and administrators, but we never heard back from any of them. This same student plays in the school’s marching band with me. This means there’s a good chance I’ll have to change in front of him for those events, too. Then, there are overnight trips, like the one I took last year for Youth and Government to visit our state capital. On those trips, school officials usually have four girls share a room. But some schools are letting males stay in those rooms, too — and often without adult chaperones around. All these things make me uncomfortable. I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl. I don’t like being that vulnerable, especially in front of someone who’s making leering, suggestive comments. For me and for most girls I know, the fact that males are participating in our sports takes all the fun out of competing. Not only does it make us feel unsafe, but the older we get, the more obvious it becomes that they’re going to beat us, more and more easily … that the records, the medals and the opportunities will be going to them. What’s the point of competing if we have no chance of winning? Why take the time and make the effort only to expose ourselves to sexual harassment and possibly worse, while coaches and administrators deliberately look the other way? Why bother to object to what’s happening when so many are waiting to call us \"transphobes\" just for expressing our feelings and concerns? Since I’m one grade above the male student I competed against, I had a small reprieve from all the frustrations I experienced in middle school. But this year, that student is entering high school. Once again, we’ll be on the same team, practicing the same sports, playing in the same band. Some people don’t seem to understand why that is a problem. I’m just glad that, at least for now, the Supreme Court did, and I hope the 6th Circuit will, too."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. Just return those viewpoints as a structured JSON object."
model='gpt-4o-mini'
temperature = 1
prompt_version = 2

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_2)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1092,
#     "output_tokens": 161,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.0002604,
# ...

# %%
user_content = "Some might wonder why a sophomore in high school — busy with classes, band and sports — sought the attention of the U.S. Supreme Court, which ruled in my favor recently. Now, I can proceed with my case at the U.S. Court of Appeals for the 6th Circuit unencumbered, for now, by Biden-Harris administration overreach. The high court denied the administration’s request to start enforcing Title IX rule changes that could have a pretty big effect on the rest of my teenage years by allowing males into women’s spaces. Title IX is the federal law designed to create equal opportunities for female students in education and athletics, and I, through my attorneys with Alliance Defending Freedom, oppose the administration’s unlawful attempts to redefine it. So do women’s groups, scholars, 20 states and others who have now filed briefs in my support at the 6th Circuit. Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex. Sharing private space is hard enough, even with a sibling, a friend or someone your same age and sex. It’s that much harder if you’re sharing with someone who’s none of those things — especially if that someone is making crude, sexually harassing comments. I put up with that all through middle school. I chose to join my school’s track team, running the 4 x 100-meter races, pole vaulting and throwing shot put and discus. It was fun, and I was competitive — one of the top three girls in my school for those latter two events. That all changed when a male a grade behind me chose to identify as a girl and joined our team — focusing on the same sports I did. As seasons passed, I soon saw how male size and strength could beat even my greatest efforts — and those of most other girls, too. Over these last two years, this one student has displaced almost 300 different female athletes — beating them in competition and taking their places at meets — over 700 times. I saw a lot of that firsthand. Almost every day, in the locker room, out on the track and in the throwing pits for discus and shot put, this student made crude, sexually explicit comments about me and other girls — many of which I found physically threatening. And yet, I was expected to change clothes in front of — and go to the restroom in the same room with — the male making those comments. Some of us began wearing school clothes to practice or our practice clothes to classes just to avoid changing in front of this one student. Yes, we complained to our coaches and administrators, but we never heard back from any of them. This same student plays in the school’s marching band with me. This means there’s a good chance I’ll have to change in front of him for those events, too. Then, there are overnight trips, like the one I took last year for Youth and Government to visit our state capital. On those trips, school officials usually have four girls share a room. But some schools are letting males stay in those rooms, too — and often without adult chaperones around. All these things make me uncomfortable. I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl. I don’t like being that vulnerable, especially in front of someone who’s making leering, suggestive comments. For me and for most girls I know, the fact that males are participating in our sports takes all the fun out of competing. Not only does it make us feel unsafe, but the older we get, the more obvious it becomes that they’re going to beat us, more and more easily … that the records, the medals and the opportunities will be going to them. What’s the point of competing if we have no chance of winning? Why take the time and make the effort only to expose ourselves to sexual harassment and possibly worse, while coaches and administrators deliberately look the other way? Why bother to object to what’s happening when so many are waiting to call us \"transphobes\" just for expressing our feelings and concerns? Since I’m one grade above the male student I competed against, I had a small reprieve from all the frustrations I experienced in middle school. But this year, that student is entering high school. Once again, we’ll be on the same team, practicing the same sports, playing in the same band. Some people don’t seem to understand why that is a problem. I’m just glad that, at least for now, the Supreme Court did, and I hope the 6th Circuit will, too."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. You will return your response as a JSON object. YOU HAVE TWO TASKS! For each type of bias, return a BREIF ANALYSIS of how the article contains that bias. Additionally, for the 'generalizations', 'unfair_statements', and 'stereotypes', return the EXACT TEXT FRAGMENTS that contain these aspects. Remember, for the 'generalizations', 'unfair_statements', and 'stereotypes' fields you are returning text from the original. For every othr fields in your JSON object you are returning an analysis of how that type of bias showed up in the article. "
model='gpt-4o-mini'
temperature = 1
prompt_version = 3

# %%
JSON_schema_3 = {
    "type": "object",
    "properties": {
      "racial_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "gender_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "age_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "religious_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "class_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "disability_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "sexual_orientation_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "cultural_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "body_size_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "nationalism_ethnocentrism": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "intersectional_bias": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "stereotypes": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "unfair_statements": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "generalizations": {
        "type": "array",
        "items": {
          "type": "string"
        }
      }
    }
  }

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_2)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1206,
#     "output_tokens": 94,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00023729999999999997,
#     "completion_string": "{\"racial_bias\":[],\"gender_bias\":[\"The narrative suggests that males (especially transgender individuals) participating in female sports inherently makes female athletes unsafe or uncomfortable, which perpetuates the idea that transgender women are a threat to cisgender women.\"],\"age_bias\":[],\"religious_bias\":[],\"class_bias\":[],\"disability_bias\":[],\"sexual_orientation_bias\":[],\"cultural_bias\":[],\"body_size_bias\":[],\"nationalism_ethnocentrism\":[],\"intersectional_bias\":[]}",
#     "prompt_version": 3,
#     "racial_bias": [],
#     "gender_bias": [
# ...

# %%
user_content = "Some might wonder why a sophomore in high school — busy with classes, band and sports — sought the attention of the U.S. Supreme Court, which ruled in my favor recently. Now, I can proceed with my case at the U.S. Court of Appeals for the 6th Circuit unencumbered, for now, by Biden-Harris administration overreach. The high court denied the administration’s request to start enforcing Title IX rule changes that could have a pretty big effect on the rest of my teenage years by allowing males into women’s spaces. Title IX is the federal law designed to create equal opportunities for female students in education and athletics, and I, through my attorneys with Alliance Defending Freedom, oppose the administration’s unlawful attempts to redefine it. So do women’s groups, scholars, 20 states and others who have now filed briefs in my support at the 6th Circuit. Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex. Sharing private space is hard enough, even with a sibling, a friend or someone your same age and sex. It’s that much harder if you’re sharing with someone who’s none of those things — especially if that someone is making crude, sexually harassing comments. I put up with that all through middle school. I chose to join my school’s track team, running the 4 x 100-meter races, pole vaulting and throwing shot put and discus. It was fun, and I was competitive — one of the top three girls in my school for those latter two events. That all changed when a male a grade behind me chose to identify as a girl and joined our team — focusing on the same sports I did. As seasons passed, I soon saw how male size and strength could beat even my greatest efforts — and those of most other girls, too. Over these last two years, this one student has displaced almost 300 different female athletes — beating them in competition and taking their places at meets — over 700 times. I saw a lot of that firsthand. Almost every day, in the locker room, out on the track and in the throwing pits for discus and shot put, this student made crude, sexually explicit comments about me and other girls — many of which I found physically threatening. And yet, I was expected to change clothes in front of — and go to the restroom in the same room with — the male making those comments. Some of us began wearing school clothes to practice or our practice clothes to classes just to avoid changing in front of this one student. Yes, we complained to our coaches and administrators, but we never heard back from any of them. This same student plays in the school’s marching band with me. This means there’s a good chance I’ll have to change in front of him for those events, too. Then, there are overnight trips, like the one I took last year for Youth and Government to visit our state capital. On those trips, school officials usually have four girls share a room. But some schools are letting males stay in those rooms, too — and often without adult chaperones around. All these things make me uncomfortable. I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl. I don’t like being that vulnerable, especially in front of someone who’s making leering, suggestive comments. For me and for most girls I know, the fact that males are participating in our sports takes all the fun out of competing. Not only does it make us feel unsafe, but the older we get, the more obvious it becomes that they’re going to beat us, more and more easily … that the records, the medals and the opportunities will be going to them. What’s the point of competing if we have no chance of winning? Why take the time and make the effort only to expose ourselves to sexual harassment and possibly worse, while coaches and administrators deliberately look the other way? Why bother to object to what’s happening when so many are waiting to call us \"transphobes\" just for expressing our feelings and concerns? Since I’m one grade above the male student I competed against, I had a small reprieve from all the frustrations I experienced in middle school. But this year, that student is entering high school. Once again, we’ll be on the same team, practicing the same sports, playing in the same band. Some people don’t seem to understand why that is a problem. I’m just glad that, at least for now, the Supreme Court did, and I hope the 6th Circuit will, too."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. You will return your response as a JSON object. Return the exact text fragments that include the following biases in the narrative: 'generalizations', 'unfair_statements', and 'stereotypes'. Return the EXACT TEXT FRAGMENTS that contain these aspects."
model='gpt-4o-mini'
temperature = 1
prompt_version = 4

# %%
JSON_schema_4 = {
    "type": "object",
    "properties": {
      "stereotypes": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "unfair_statements": {
        "type": "array",
        "items": {
          "type": "string"
        }
      },
      "generalizations": {
        "type": "array",
        "items": {
          "type": "string"
        }
      }
    }
  }

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_4)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1088,
#     "output_tokens": 109,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.0002286,
#     "completion_string": "{\"stereotypes\":[\"males are participating in our sports takes all the fun out of competing\",\"that the records, the medals and the opportunities will be going to them\"],\"unfair_statements\":[\"expected to change clothes in front of \u2014 and go to the restroom in the same room with \u2014 the male making those comments\",\"while coaches and administrators deliberately look the other way\"],\"generalizations\":[\"Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex\",\"For me and for most girls I know,\"]}",
#     "prompt_version": 4,
#     "stereotypes": [
#         "males are participating in our sports takes all the fun out of competing",
# ...

# %% [markdown]
# # **Code**

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.0/383.0 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import os
import json
import pprint
from openai import OpenAI

# %% [markdown]
# This section ensures that the OpenAI library is properly set up to make authorized API calls using the specified API key.

# %%
from google.colab import userdata

OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

openai = OpenAI(api_key=OPENAI_API_KEY)

# %%
model_pricing = {
    "gpt-4o": {
        "input_token_cost": 0.005,
        "output_token_cost": 0.015
    },
    "gpt-4o-2024-08-06": {
        "input_token_cost": 0.00250,
        "output_token_cost": 0.01
    },
    "gpt-4o-mini": {
        "input_token_cost": 0.00015,
        "output_token_cost": 0.0006
    },
    "gpt-4o-mini-2024-07-18": {
        "input_token_cost": 0.00015,
        "output_token_cost": 0.0006
    }
}

# %%
def get_analysis_openai(system_content: str, user_content: str, model: str, temperature: float = 1.0, prompt_version: int = 1, JSON_schema: object = {}):
    print(f"calling get_analysis_openai with model: {model}")

    try:
        response = openai.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": user_content},
            ],
            temperature=1,
            response_format={"type": "json_object"},
            tools=[{
                "type": "function",
                "function": {
                    "name": "JSON_biases_detected",
                    "description":"Extract biases from a given text; return a JSON object",
                    "parameters": JSON_schema
                }
            }],
            tool_choice={"type": "function", "function": {"name": "JSON_biases_detected"}},
        )

        completion_string = response.choices[0].message.tool_calls[0].function.arguments
        usage = response.usage

        input_tokens = usage.prompt_tokens
        output_tokens = usage.completion_tokens
        pricing = model_pricing[model]
        input_cost = pricing['input_token_cost']
        output_cost = pricing['output_token_cost']

        prediction_cost = ((input_tokens / 1000 * input_cost) + (output_tokens / 1000 * output_cost))


        response_data = {
            'model': model,
            'temperature': temperature,
            'input_tokens': input_tokens,
            'output_tokens': output_tokens,
            'input_cost': input_cost,
            'output_cost': output_cost,
            'prediction_cost': prediction_cost,
            'completion_string': completion_string,
            'prompt_version': prompt_version
        }

        # Parse completion string
        try:
            completion_data = json.loads(completion_string)
            response_data.update(completion_data)
        except json.JSONDecodeError:
            pass

        return response_data

        # return response

    except Exception as e:
        print("Error getting OpenAI completion data:", e)
        return {'error': str(e)}

# %% [markdown]
# Below is the text that will be used to run the function: AnalyzeText

# %%
JSON_schema_5 = {
    "type": "object",
    "properties": {
      "racial_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "gender_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "age_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "religious_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "class_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "disability_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "sexual_orientation_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "cultural_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "body_size_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "nationalism_ethnocentrism": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "intersectional_bias": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "stereotypes": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "unfair_statements": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      },
      "generalizations": {
        "type": "array",
        "items": {
          "type": "object",
          "properties": {
            "excerpt": {
              "type": "string"
            },
            "explanation": {
              "type": "string"
            }
          },
        },
      }
      }
  }

# %%
user_content = "Some might wonder why a sophomore in high school — busy with classes, band and sports — sought the attention of the U.S. Supreme Court, which ruled in my favor recently. Now, I can proceed with my case at the U.S. Court of Appeals for the 6th Circuit unencumbered, for now, by Biden-Harris administration overreach. The high court denied the administration’s request to start enforcing Title IX rule changes that could have a pretty big effect on the rest of my teenage years by allowing males into women’s spaces. Title IX is the federal law designed to create equal opportunities for female students in education and athletics, and I, through my attorneys with Alliance Defending Freedom, oppose the administration’s unlawful attempts to redefine it. So do women’s groups, scholars, 20 states and others who have now filed briefs in my support at the 6th Circuit. Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex. Sharing private space is hard enough, even with a sibling, a friend or someone your same age and sex. It’s that much harder if you’re sharing with someone who’s none of those things — especially if that someone is making crude, sexually harassing comments. I put up with that all through middle school. I chose to join my school’s track team, running the 4 x 100-meter races, pole vaulting and throwing shot put and discus. It was fun, and I was competitive — one of the top three girls in my school for those latter two events. That all changed when a male a grade behind me chose to identify as a girl and joined our team — focusing on the same sports I did. As seasons passed, I soon saw how male size and strength could beat even my greatest efforts — and those of most other girls, too. Over these last two years, this one student has displaced almost 300 different female athletes — beating them in competition and taking their places at meets — over 700 times. I saw a lot of that firsthand. Almost every day, in the locker room, out on the track and in the throwing pits for discus and shot put, this student made crude, sexually explicit comments about me and other girls — many of which I found physically threatening. And yet, I was expected to change clothes in front of — and go to the restroom in the same room with — the male making those comments. Some of us began wearing school clothes to practice or our practice clothes to classes just to avoid changing in front of this one student. Yes, we complained to our coaches and administrators, but we never heard back from any of them. This same student plays in the school’s marching band with me. This means there’s a good chance I’ll have to change in front of him for those events, too. Then, there are overnight trips, like the one I took last year for Youth and Government to visit our state capital. On those trips, school officials usually have four girls share a room. But some schools are letting males stay in those rooms, too — and often without adult chaperones around. All these things make me uncomfortable. I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl. I don’t like being that vulnerable, especially in front of someone who’s making leering, suggestive comments. For me and for most girls I know, the fact that males are participating in our sports takes all the fun out of competing. Not only does it make us feel unsafe, but the older we get, the more obvious it becomes that they’re going to beat us, more and more easily … that the records, the medals and the opportunities will be going to them. What’s the point of competing if we have no chance of winning? Why take the time and make the effort only to expose ourselves to sexual harassment and possibly worse, while coaches and administrators deliberately look the other way? Why bother to object to what’s happening when so many are waiting to call us \"transphobes\" just for expressing our feelings and concerns? Since I’m one grade above the male student I competed against, I had a small reprieve from all the frustrations I experienced in middle school. But this year, that student is entering high school. Once again, we’ll be on the same team, practicing the same sports, playing in the same band. Some people don’t seem to understand why that is a problem. I’m just glad that, at least for now, the Supreme Court did, and I hope the 6th Circuit will, too."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. You will return your response as a JSON object. Return any text fragments that include the following biases in the narrative: racial_bias, gender_bias, age_bias, religious_bias, class_bias, disability_bias, sexual_orientation_bias, cultural_bias, body_size_bias, marginalism_ethnocentrism, intersectional_bias, also look for 'generalizations', 'unfair_statements', and 'stereotypes'. Return the EXACT TEXT FRAGMENTS that contain these aspects along with an analysis of how that fragment relates to that particular bias."
model='gpt-4o-mini'
temperature = 1
prompt_version = 5

# %%
test_run = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_5)

print(json.dumps(test_run, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1316,
#     "output_tokens": 499,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.0004967999999999999,
# ...

# %% [markdown]
# The "cumulative_biases" dictionary is created to store different categories of the detected biases. This dictonary will be later used to provide the user with a summary of the baises they have been exposed to over time.

# %%
cumulative_biases = {
    "racial_bias": [],
    "gender_bias": [],
    "age_bias": [],
    "religious_bias": [],
    "class_bias": [],
    "disability_bias": [],
    "sexual_orientation_bias": [],
    "cultural_bias": [],
    "body_size_bias": [],
    "nationalism_ethnocentrism": [],
    "intersectional_bias": [],
    "unfair_statements": [],
    "stereotypes": [],
    "generalizations": []
}

# %%
print(cumulative_biases)
# Out:
# {'racial_bias': [], 'gender_bias': [{'excerpt': 'allowing males into women’s spaces', 'explanation': 'This statement suggests that male presence in spaces designated for women poses a problem, which perpetuates a bias against transgender individuals and reinforces binary views of gender.'}, {'excerpt': 'Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex.', 'explanation': 'This generalization implies that all teenagers share the same discomfort, reinforcing a stereotype about gender segregation.'}, {'excerpt': 'I don’t like showering or sleeping in the same room with a male, even if he identifies as a girl.', 'explanation': 'This statement dismisses the identity of transgender individuals and reinforces a negative bias towards those who identify outside of the traditional gender binary.'}, {'excerpt': 'What’s the point of competing if we have no chance of winning?', 'explanation': 'This reflects a gender bias that implies women’s spo
# ...

# %% [markdown]
# This updates the "biases" dictionary with the different baises everytime a test run is executed. This updates everytime the extention detects biases.

# %%
def extend_biases(response):
  if "racial_bias" in response:
      cumulative_biases["racial_bias"].extend(response["racial_bias"])
  if "gender_bias" in response:
    cumulative_biases["gender_bias"].extend(response["gender_bias"])
  if "age_bias" in response:
    cumulative_biases["age_bias"].extend(response["age_bias"])
  if "religious_bias" in response:
    cumulative_biases["religious_bias"].extend(response["religious_bias"])
  if "class_bias" in response:
    cumulative_biases["class_bias"].extend(response["class_bias"])
  if "disability_bias" in response:
    cumulative_biases["disability_bias"].extend(response["disability_bias"])
  if "sexual_orientation_bias" in response:
    cumulative_biases["sexual_orientation_bias"].extend(response["sexual_orientation_bias"])
  if "cultural_bias" in response:
    cumulative_biases["cultural_bias"].extend(response["cultural_bias"])
  if "body_size_bias" in response:
    cumulative_biases["body_size_bias"].extend(response["body_size_bias"])
  if "nationalism_ethnocentrism" in response:
    cumulative_biases["nationalism_ethnocentrism"].extend(response["nationalism_ethnocentrism"])
  if "intersectional_bias" in response:
    cumulative_biases["intersectional_bias"].extend(response["intersectional_bias"])
  if "generalizations" in response:
    cumulative_biases["generalizations"].extend(response["generalizations"])
  if "stereotypes" in response:
    cumulative_biases["stereotypes"].extend(response["stereotypes"])
  if "unfair_statements" in response:
    cumulative_biases["unfair_statements"].extend(response["unfair_statements"])

# %%
response = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_5)

print(json.dumps(response, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1316,
#     "output_tokens": 456,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00047099999999999996,
# ...

# %%
extend_biases(response);

print(json.dumps(cumulative_biases, indent=4))
# Out:
# {
#     "racial_bias": [],
#     "gender_bias": [
#         {
#             "excerpt": "allowing males into women\u2019s spaces",
#             "explanation": "This statement suggests that male presence in spaces designated for women poses a problem, which perpetuates a bias against transgender individuals and reinforces binary views of gender."
#         },
#         {
#             "excerpt": "Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex.",
#             "explanation": "This generalization implies that all teenagers share the same discomfort, reinforcing a stereotype about gender segregation."
#         },
#         {
#             "excerpt": "I don\u2019t like showering or sleeping in the same room with a male, even if he identifies as a girl.",
# ...

# %%
user_content = "The Most Important Question Kamala Harris Hasn’t Answered Sept. 28, 2024, 7:00 a.m. ET Vice President Kamala Harris with President Volodymyr Zelensky of Ukraine.Credit...Damon Winter/The New York Times Share full article 626 Ross Douthat By Ross Douthat Opinion Columnist Want to stay updated on what’s happening in Afghanistan, Russia and Ukraine? Sign up for Your Places: Global Update, and we’ll send our latest coverage to your inbox. Not all the policy questions left unanswered by Kamala Harris’s studiously vague presidential campaign are created equal. It is not especially urgent, for instance, to know how Harris’s views of the ideal health care system have evolved since the great Medicare for All debates of 2020, given the strong likelihood that as president she would share power with a Republican Congress and any sweeping domestic policy initiatives would be stillborn. It is rather more important, on the other hand, to know what a President Harris would do about the war in Ukraine, the most significant crisis that she would immediately inherit. With Volodymyr Zelensky in Washington this week, we were treated to a formal restatement of Harris’s support for the Biden administration’s position from early in the war, which envisioned Ukraine taking back most of its lost territory: Standing beside the Ukrainian leader, the vice president dismissed any deal making that involves territorial concessions as Putinist fellow-traveling and “proposals for surrender.” (The intended contrast with Donald Trump is obvious, since Trump is promising to immediately seek an armistice even as he declines to detail terms.) But even as the vice president was issuing this statement, the administration was leaking doubts about Zelensky’s supposed plan for victory, dismissing it as “little more than a repackaged request for more weapons and the lifting of restrictions on long-range missiles,” to quote The Wall Street Journal. In other words, it’s a request for help to slow the grinding pace of Russian gains, but not a plan to actually deliver the victorious endgame that Kyiv and Washington have officially been seeking. In fairness to Zelensky, it’s not clear what form such a plan could take, absent the direct NATO intervention that the Biden White House has prudently resisted. The situation on the front has turned against Ukraine over the last year, with the main question right now being just how bad things are likely to get. The Economist, speaking for some part of the Western establishment, has an intensely pessimistic assessment in its latest issue, emphasizing Russian advantages in numbers, firepower and cash. Cathy Young, writing for The Bulwark, has a more optimistic take, arguing that the current Russian push may hit its limits soon, that Moscow may be hoping “to seize as much land as they can by winter, in hopes of getting a cease-fire deal that freezes the territorial status quo.” But both readings converge on the reality that for now Ukraine’s main goal is to stabilize the front, and the hope of a rapid Russian retreat that many hawks nurtured in 2022 and 2023 has slipped away. Such a situation presents two levels of uncertainty about what a Harris administration might decide to do. The immediate questions are how long the United States can persist in supporting a “plan” for victory that does not actually exist, to what extent Trump’s call for negotiations is a likely endpoint for U.S. policy no matter which candidate wins in November, and whether both the Biden White House and Harris herself are just hoping Ukraine holds the line through the election — at which point their no-negotiation stance may become a lot more flexible. The longer-term questions involve the place of Ukraine in American grand strategy, which is dealing with a range of dangerous stress points at the moment. The initial hope that the Ukraine war would neutralize one of our challengers looks relatively vain: Russia has weathered our economic warfare and seems to be thriving, for now, with a war economy deeply integrated with our more significant rivals in Beijing. And that Sino-Russian integration is a key part of a landscape that a recent bipartisan report by the Commission on the National Defense Strategy called “the most serious and most challenging the nation has encountered since 1945,” in terms of our vulnerabilities to our major adversaries and “the potential for near-term major war.” There may be some hyperbole in that assessment, but certainly this is the most fraught moment for American power since the end of the Cold War, with challenges on a scale that requires either substantial rearmament, meaningful retrenchment or some combination of the two. And the current White House has struggled with this balance, first retrenching chaotically in Afghanistan, and thereafter responding to new crises by doubling down on America’s promises — but without a clear plan to make those commitments sustainable, to match our rhetoric with underlying strength. Ukraine in this context isn’t just a major strategic problem in its own right but one decision point among many, from the Middle East to East and Northeast Asia, that will test the next president’s ability to set priorities, recalibrate commitments and match our expansive ends with our more limited means. Does Harris have a different vision from the current president on how to defend the Pax Americana? Does she have any specific vision? None of the unanswered questions about her candidacy are likely to matter more, or have answers that cost more if the world does not cooperate."
system_content = "You are a social bias detection tool. Analyze the following text and identify how the narrative contains or perpetuates social biases. You will return your response as a JSON object. Return any text fragments that include the following biases in the narrative: racial_bias, gender_bias, age_bias, religious_bias, class_bias, disability_bias, sexual_orientation_bias, cultural_bias, body_size_bias, marginalism_ethnocentrism, intersectional_bias, also look for 'generalizations', 'unfair_statements', and 'stereotypes'. Return the EXACT TEXT FRAGMENTS that contain these aspects along with an analysis of how that fragment relates to that particular bias."
model='gpt-4o-mini'
temperature = 1
prompt_version = 5

# %%
response = get_analysis_openai(system_content, user_content, model, temperature, prompt_version, JSON_schema=JSON_schema_5)

print(json.dumps(response, indent=4))
# Out:
# calling get_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 1474,
#     "output_tokens": 218,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00035189999999999993,
# ...

# %%
extend_biases(response);

print(json.dumps(cumulative_biases, indent=4))
# Out:
# {
#     "racial_bias": [],
#     "gender_bias": [
#         {
#             "excerpt": "allowing males into women\u2019s spaces",
#             "explanation": "This statement suggests that male presence in spaces designated for women poses a problem, which perpetuates a bias against transgender individuals and reinforces binary views of gender."
#         },
#         {
#             "excerpt": "Most teenagers are uncomfortable sharing restrooms, locker rooms and hotel rooms with the opposite sex.",
#             "explanation": "This generalization implies that all teenagers share the same discomfort, reinforcing a stereotype about gender segregation."
#         },
#         {
#             "excerpt": "I don\u2019t like showering or sleeping in the same room with a male, even if he identifies as a girl.",
# ...

# %%
def get_cumulative_analysis_openai(system_content: str, user_content: str, model: str, temperature: float = 1.0, prompt_version: int = 1):
    print(f"calling get_cumulative_analysis_openai with model: {model}")

    try:
        response = openai.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": f"Cumulative bias object: {user_content}. Return an analysis of the social biases that the user is exposing themselves to."},
            ],
            temperature=1,

        )


        completion_string = response.choices[0].message.content

        usage = response.usage

        input_tokens = usage.prompt_tokens
        output_tokens = usage.completion_tokens
        pricing = model_pricing[model]
        input_cost = pricing['input_token_cost']
        output_cost = pricing['output_token_cost']

        prediction_cost = ((input_tokens / 1000 * input_cost) + (output_tokens / 1000 * output_cost))


        response_data = {
            'model': model,
            'temperature': temperature,
            'input_tokens': input_tokens,
            'output_tokens': output_tokens,
            'input_cost': input_cost,
            'output_cost': output_cost,
            'prediction_cost': prediction_cost,
            'completion_string': completion_string,
            'prompt_version': prompt_version
        }

        return response_data

    except Exception as e:
        print("Error getting OpenAI completion data:", e)
        return {'error': str(e)}

# %%
user_content = json.dumps(cumulative_biases)
system_content = "The following object represents cumulative bias that a reader has been exposed to over a series of articles. Come up with an analysis of the social biases that the user is exposing themselves to. Pay particular attention to the subtle ways in which biases show up. Return your analysis as a short, readable analysis. Get straight to the point, do not provide an intro or conclusion."
model='gpt-4o-mini'
temperature = 1
prompt_version = 5

# %%
response = get_cumulative_analysis_openai(system_content, user_content, model, temperature, prompt_version)

print(json.dumps(response, indent=4))
# Out:
# calling get_cumulative_analysis_openai with model: gpt-4o-mini
# {
#     "model": "gpt-4o-mini",
#     "temperature": 1,
#     "input_tokens": 773,
#     "output_tokens": 299,
#     "input_cost": 0.00015,
#     "output_cost": 0.0006,
#     "prediction_cost": 0.00029535,
# ...

# %%
gent, for instance, to know how Harris’s views of the ideal health care system have evolved since the great Medicare for All debates of 2020, given the strong likelihood that as president she would share power with a Republican Congress and any sweeping domestic policy initiatives would be stillborn. It is rather more important, on the other hand, to know what a President Harris would do about the war in Ukraine, the most significant crisis that she would immediately inherit. With Volodymyr Zelensky in Washington this week, we were treated to a formal restatement of Harris’s support for the Biden administration’s position from early in the war, which envisioned Ukraine taking back most of its lost territory: Standing beside the Ukrainian leader, the vice president dismissed any deal making that involves territorial concessions as Putinist fellow-traveling and “proposals for surrender.” (The intended contrast with Donald Trump is obvious, since Trump is promising to immediately seek an armistice even as he declines to detail terms.) But even as the vice president was issuing this statement, the administration was leaking doubts about Zelensky’s supposed plan for victory, dismissing it as “little more than a repackaged request for more weapons and the lifting of restrictions on long-range missiles,” to quote The Wall Street Journal. In other words, it’s a request for help to slow the grinding pace of Russian gains, but not a plan to actually deliver the victorious endgame that Kyiv and Washington have officially been seeking. In fairness to Zelensky, it’s not clear what form such a plan could take, absent the direct NATO intervention that the Biden White House has prudently resisted. The situation on the front has turned against Ukraine over the last year, with the main question right now being just how bad things are likely to get. The Economist, speaking for some part of the Western establishment, has an intensely pessimistic assessment in its latest issue, emphasizing Russian advantages in numbers, firepower and cash. Cathy Young, writing for The Bulwark, has a more optimistic take, arguing that the current Russian push may hit its limits soon, that Moscow may be hoping “to seize as much land as they can by winter, in hopes of getting a cease-fire deal that freezes the territorial status quo.” But both readings converge on the reality that for now Ukraine’s main goal is to stabilize the front, and the hope of a rapid Russian retreat that many hawks nurtured in 2022 and 2023 has slipped away. Such a situation presents two levels of uncertainty about what a Harris administration might decide to do. The immediate questions are how long the United States can persist in supporting a “plan” for victory that does not actually exist, to what extent Trump’s call for negotiations is a likely endpoint for U.S. policy no matter which candidate wins in November, and whether both the Biden White House and Harris herself are just hoping Ukraine holds the line through the election — at which point their no-negotiation stance may become a lot more flexible. The longer-term questions involve the place of Ukraine in American grand strategy, which is dealing with a range of dangerous stress points at the moment. The initial hope that the Ukraine war would neutralize one of our challengers looks relatively vain: Russia has weathered our economic warfare and seems to be thriving, for now, with a war economy deeply integrated with our more significant rivals in Beijing. And that Sino-Russian integration is a key part of a landscape that a recent bipartisan report by the Commission on the National Defense Strategy called “the most serious and most challenging the nation has encountered since 1945,” in terms of our vulnerabilities to our major adversaries and “the potential for near-term major war.” There may be some hyperbole in that assessment, but certainly this is the most fraught moment for American power since the end of the Cold War, with challenges on a scale that requires either substantial rearmament, meaningful retrenchment or some combination of the two. And the current White House has struggled with this balance, first retrenching chaotically in Afghanistan, and thereafter responding to new crises by doubling down on America’s promises — but without a clear plan to make those commitments sustainable, to match our rhetoric with underlying strength. Ukraine in this context isn’t just a major strategic problem in its own right but one decision point among many, from the Middle East to East and Northeast Asia, that will test the next president’s ability to set priorities, recalibrate commitments and match our expansive ends with our more limited means. Does Harris have a different vision from the current president on how to defend the Pax Americana? Does she have any specific vision? None of the unanswered questions about her candidacy are likely to matter more, or have answers that cost more if the world does not cooperate.",
]
